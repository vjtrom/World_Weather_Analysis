# %% [markdown]
# Deliverable 1: Retrieve Weather Data

# %%
# Import Dependencies
import numpy as np
import pandas as pd
import citipy as citipy
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a new set of 2,000 random latitudes and longitudes
longitudes = np.random.uniform(-180.000, 180.000, size=2000)
latitudes = np.random.uniform(-90.000, 90.000, size=2000)
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Identify the nearest city for each latitude and longitude combination.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
# Perform an API call with the OpenWeatherMap

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = round(city_weather["coord"]["lat"],2)
        city_lng = round(city_weather["coord"]["lon"],2)
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description.title()})
                          #"Date": city_date})
      

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 2 of Set 1 | magadan
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | nikolskoye
# Processing Record 5 of Set 1 | touros
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | adrar
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | teguise
# Processing Record 11 of Set 1 | praia da vitoria
# Processing Record 12 of Set 1 | namibe
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | kangaatsiaq
# Processing Record 15 of Set 1 | gondanglegi
# Processing Record 16 of Set 1 | porto novo
# Processing Record 17 of Set 1 | mayumba
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | pangnirtung
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | suntar
# Processing Record 23 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 1 | tasiilaq
# Processing Record 25 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 1 | vizinga
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | suao
# City not found. Skipping...
# Processing Record 31 of Set 1 | arraial do cabo
# Processing Record 32 of Set 1 | baghdad
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | lavrentiya
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | camacupa
# Processing Record 37 of Set 1 | iberia
# Processing Record 38 of Set 1 | priverno
# Processing Record 39 of Set 1 | petroton
# City not found. Skipping...
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | north bend
# Processing Record 42 of Set 1 | ponta do sol
# Processing Record 43 of Set 1 | kaeo
# Processing Record 44 of Set 1 | vossevangen
# Processing Record 45 of Set 1 | saint-francois
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | sao filipe
# Processing Record 50 of Set 1 | kruisfontein
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | kavieng
# Processing Record 3 of Set 2 | upernavik
# Processing Record 4 of Set 2 | taoudenni
# Processing Record 5 of Set 2 | paragominas
# Processing Record 6 of Set 2 | chute-aux-outardes
# Processing Record 7 of Set 2 | geraldton
# Processing Record 8 of Set 2 | tiznit
# Processing Record 9 of Set 2 | havre-saint-pierre
# Processing Record 10 of Set 2 | dingle
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | padang
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | lagoa
# Processing Record 15 of Set 2 | pevek
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | kati
# Processing Record 18 of Set 2 | natal
# Processing Record 19 of Set 2 | kiama
# Processing Record 20 of Set 2 | berceni
# Processing Record 21 of Set 2 | manali
# Processing Record 22 of Set 2 | alice springs
# Processing Record 23 of Set 2 | kamloops
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | dongsheng
# Processing Record 26 of Set 2 | piacabucu
# Processing Record 27 of Set 2 | camarillo
# Processing Record 28 of Set 2 | airai
# Processing Record 29 of Set 2 | fortuna
# Processing Record 30 of Set 2 | bud
# Processing Record 31 of Set 2 | nadym
# Processing Record 32 of Set 2 | kaitangata
# Processing Record 33 of Set 2 | garowe
# Processing Record 34 of Set 2 | college
# Processing Record 35 of Set 2 | sao joao da barra
# Processing Record 36 of Set 2 | port augusta
# Processing Record 37 of Set 2 | cape town
# Processing Record 38 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 2 | codrington
# Processing Record 40 of Set 2 | akdepe
# Processing Record 41 of Set 2 | wanning
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | olmos
# Processing Record 44 of Set 2 | silute
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | matadi
# Processing Record 47 of Set 2 | ancud
# Processing Record 48 of Set 2 | kahului
# Processing Record 49 of Set 2 | hami
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | ashqelon
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | taltal
# Processing Record 4 of Set 3 | kismayo
# Processing Record 5 of Set 3 | mahibadhoo
# Processing Record 6 of Set 3 | sambava
# Processing Record 7 of Set 3 | blagoyevo
# Processing Record 8 of Set 3 | sinnamary
# Processing Record 9 of Set 3 | sur
# Processing Record 10 of Set 3 | hambantota
# Processing Record 11 of Set 3 | olafsvik
# Processing Record 12 of Set 3 | meulaboh
# Processing Record 13 of Set 3 | eydhafushi
# Processing Record 14 of Set 3 | moree
# Processing Record 15 of Set 3 | luganville
# Processing Record 16 of Set 3 | qaanaaq
# Processing Record 17 of Set 3 | tuatapere
# Processing Record 18 of Set 3 | klaksvik
# Processing Record 19 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of Set 3 | vostok
# Processing Record 21 of Set 3 | muros
# Processing Record 22 of Set 3 | bluff
# Processing Record 23 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 3 | saldanha
# Processing Record 25 of Set 3 | ambilobe
# Processing Record 26 of Set 3 | mata grande
# Processing Record 27 of Set 3 | puerto ayora
# Processing Record 28 of Set 3 | leningradskiy
# Processing Record 29 of Set 3 | jasper
# Processing Record 30 of Set 3 | santa isabel
# Processing Record 31 of Set 3 | novyy urengoy
# Processing Record 32 of Set 3 | bredasdorp
# Processing Record 33 of Set 3 | vaini
# Processing Record 34 of Set 3 | bubaque
# Processing Record 35 of Set 3 | esperance
# Processing Record 36 of Set 3 | namwala
# Processing Record 37 of Set 3 | port hardy
# Processing Record 38 of Set 3 | bo rai
# Processing Record 39 of Set 3 | wanxian
# Processing Record 40 of Set 3 | atuona
# Processing Record 41 of Set 3 | carnarvon
# Processing Record 42 of Set 3 | harper
# Processing Record 43 of Set 3 | pangkalanbuun
# Processing Record 44 of Set 3 | clyde river
# Processing Record 45 of Set 3 | albany
# Processing Record 46 of Set 3 | sao jose da coroa grande
# Processing Record 47 of Set 3 | tigil
# Processing Record 48 of Set 3 | hasaki
# Processing Record 49 of Set 3 | boa vista
# Processing Record 50 of Set 3 | saint-georges
# Processing Record 1 of Set 4 | khatanga
# Processing Record 2 of Set 4 | sibolga
# Processing Record 3 of Set 4 | provideniya
# Processing Record 4 of Set 4 | rio grande
# Processing Record 5 of Set 4 | nantucket
# Processing Record 6 of Set 4 | vardo
# Processing Record 7 of Set 4 | nouakchott
# Processing Record 8 of Set 4 | portales
# Processing Record 9 of Set 4 | sokoni
# Processing Record 10 of Set 4 | qasigiannguit
# Processing Record 11 of Set 4 | mayo
# Processing Record 12 of Set 4 | bardiyah
# Processing Record 13 of Set 4 | batagay-alyta
# Processing Record 14 of Set 4 | svetlogorsk
# Processing Record 15 of Set 4 | kitimat
# Processing Record 16 of Set 4 | vila velha
# Processing Record 17 of Set 4 | zatoka
# Processing Record 18 of Set 4 | fairbanks
# Processing Record 19 of Set 4 | soskovo
# Processing Record 20 of Set 4 | xiaolingwei
# Processing Record 21 of Set 4 | victoria
# Processing Record 22 of Set 4 | coquimbo
# Processing Record 23 of Set 4 | egvekinot
# Processing Record 24 of Set 4 | naftah
# City not found. Skipping...
# Processing Record 25 of Set 4 | castro
# Processing Record 26 of Set 4 | scarborough
# Processing Record 27 of Set 4 | norman wells
# Processing Record 28 of Set 4 | broken hill
# Processing Record 29 of Set 4 | sao mateus do sul
# Processing Record 30 of Set 4 | ondangwa
# Processing Record 31 of Set 4 | lanas
# Processing Record 32 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 4 | saint george
# Processing Record 34 of Set 4 | pareora
# Processing Record 35 of Set 4 | marawi
# Processing Record 36 of Set 4 | bengkulu
# Processing Record 37 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 4 | miyako
# Processing Record 39 of Set 4 | flinders
# Processing Record 40 of Set 4 | fuerte
# Processing Record 41 of Set 4 | cayenne
# Processing Record 42 of Set 4 | mollendo
# Processing Record 43 of Set 4 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 44 of Set 4 | caloundra
# Processing Record 45 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 46 of Set 4 | kenai
# Processing Record 47 of Set 4 | thompson
# Processing Record 48 of Set 4 | abu dhabi
# Processing Record 49 of Set 4 | sao miguel do araguaia
# Processing Record 50 of Set 4 | quartucciu
# Processing Record 1 of Set 5 | aranos
# Processing Record 2 of Set 5 | prescott
# Processing Record 3 of Set 5 | ghanzi
# Processing Record 4 of Set 5 | pierre
# Processing Record 5 of Set 5 | lazaro cardenas
# Processing Record 6 of Set 5 | bambous virieux
# Processing Record 7 of Set 5 | hobyo
# Processing Record 8 of Set 5 | saskylakh
# Processing Record 9 of Set 5 | vanimo
# Processing Record 10 of Set 5 | sobolevo
# Processing Record 11 of Set 5 | khorixas
# Processing Record 12 of Set 5 | russell
# Processing Record 13 of Set 5 | severo-kurilsk
# Processing Record 14 of Set 5 | bergama
# Processing Record 15 of Set 5 | mendahara
# City not found. Skipping...
# Processing Record 16 of Set 5 | baykit
# Processing Record 17 of Set 5 | salalah
# Processing Record 18 of Set 5 | hazleton
# Processing Record 19 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 5 | krasne
# Processing Record 21 of Set 5 | gunzburg
# Processing Record 22 of Set 5 | victoria point
# Processing Record 23 of Set 5 | tessaoua
# Processing Record 24 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 5 | fairlie
# Processing Record 26 of Set 5 | ostersund
# Processing Record 27 of Set 5 | alto longa
# Processing Record 28 of Set 5 | la ligua
# Processing Record 29 of Set 5 | magistralnyy
# Processing Record 30 of Set 5 | alyangula
# Processing Record 31 of Set 5 | poquoson
# Processing Record 32 of Set 5 | torbay
# Processing Record 33 of Set 5 | kichera
# Processing Record 34 of Set 5 | usinsk
# Processing Record 35 of Set 5 | tiksi
# Processing Record 36 of Set 5 | palauig
# Processing Record 37 of Set 5 | saint anthony
# Processing Record 38 of Set 5 | faya
# Processing Record 39 of Set 5 | husavik
# Processing Record 40 of Set 5 | mangrol
# Processing Record 41 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 5 | gurgan
# City not found. Skipping...
# Processing Record 43 of Set 5 | lawton
# Processing Record 44 of Set 5 | dunedin
# Processing Record 45 of Set 5 | chuy
# Processing Record 46 of Set 5 | aykhal
# Processing Record 47 of Set 5 | lorengau
# Processing Record 48 of Set 5 | valenca do piaui
# Processing Record 49 of Set 5 | kokopo
# Processing Record 50 of Set 5 | berlevag
# Processing Record 1 of Set 6 | cabo san lucas
# Processing Record 2 of Set 6 | sarangani
# Processing Record 3 of Set 6 | kodiak
# Processing Record 4 of Set 6 | camacha
# Processing Record 5 of Set 6 | goderich
# Processing Record 6 of Set 6 | visby
# Processing Record 7 of Set 6 | karpuninskiy
# City not found. Skipping...
# Processing Record 8 of Set 6 | rocha
# Processing Record 9 of Set 6 | belyy yar
# Processing Record 10 of Set 6 | santa maria do suacui
# Processing Record 11 of Set 6 | mayskiy
# Processing Record 12 of Set 6 | reitz
# Processing Record 13 of Set 6 | isla mujeres
# Processing Record 14 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 16 of Set 6 | tautira
# Processing Record 17 of Set 6 | sharjah
# Processing Record 18 of Set 6 | plavsk
# Processing Record 19 of Set 6 | luderitz
# Processing Record 20 of Set 6 | hobart
# Processing Record 21 of Set 6 | lata
# Processing Record 22 of Set 6 | sakyla
# Processing Record 23 of Set 6 | chumikan
# Processing Record 24 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 25 of Set 6 | colinas
# Processing Record 26 of Set 6 | duz
# City not found. Skipping...
# Processing Record 27 of Set 6 | port macquarie
# Processing Record 28 of Set 6 | ulaanbaatar
# Processing Record 29 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 6 | rioja
# Processing Record 31 of Set 6 | pachuca
# Processing Record 32 of Set 6 | arlit
# Processing Record 33 of Set 6 | buritis
# Processing Record 34 of Set 6 | san patricio
# Processing Record 35 of Set 6 | half moon bay
# Processing Record 36 of Set 6 | cherskiy
# Processing Record 37 of Set 6 | homer
# Processing Record 38 of Set 6 | avera
# Processing Record 39 of Set 6 | general higinio morinigo
# Processing Record 40 of Set 6 | petrovskoye
# Processing Record 41 of Set 6 | jiayuguan
# Processing Record 42 of Set 6 | broome
# Processing Record 43 of Set 6 | solnechnyy
# Processing Record 44 of Set 6 | cape coast
# Processing Record 45 of Set 6 | koratla
# Processing Record 46 of Set 6 | bathsheba
# Processing Record 47 of Set 6 | burns lake
# Processing Record 48 of Set 6 | zyryanka
# Processing Record 49 of Set 6 | newark
# Processing Record 50 of Set 6 | buraydah
# Processing Record 1 of Set 7 | zheleznodorozhnyy
# Processing Record 2 of Set 7 | ust-maya
# Processing Record 3 of Set 7 | basqal
# Processing Record 4 of Set 7 | hay river
# Processing Record 5 of Set 7 | zhanakorgan
# Processing Record 6 of Set 7 | mareeba
# Processing Record 7 of Set 7 | itarema
# Processing Record 8 of Set 7 | beloha
# Processing Record 9 of Set 7 | gotsu
# Processing Record 10 of Set 7 | longyearbyen
# Processing Record 11 of Set 7 | kirakira
# Processing Record 12 of Set 7 | santa cruz de tenerife
# Processing Record 13 of Set 7 | talnakh
# Processing Record 14 of Set 7 | rong kwang
# Processing Record 15 of Set 7 | laguna
# Processing Record 16 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 17 of Set 7 | bollnas
# Processing Record 18 of Set 7 | kharan
# Processing Record 19 of Set 7 | wuwei
# Processing Record 20 of Set 7 | terrace
# Processing Record 21 of Set 7 | snezhnogorsk
# Processing Record 22 of Set 7 | arman
# Processing Record 23 of Set 7 | noumea
# Processing Record 24 of Set 7 | matara
# Processing Record 25 of Set 7 | komsomolskiy
# Processing Record 26 of Set 7 | carballo
# Processing Record 27 of Set 7 | bandarbeyla
# Processing Record 28 of Set 7 | shibetsu
# Processing Record 29 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 30 of Set 7 | bethel
# Processing Record 31 of Set 7 | ust-kulom
# Processing Record 32 of Set 7 | gigmoto
# Processing Record 33 of Set 7 | poum
# Processing Record 34 of Set 7 | sonoita
# Processing Record 35 of Set 7 | road town
# Processing Record 36 of Set 7 | roald
# Processing Record 37 of Set 7 | diego de almagro
# Processing Record 38 of Set 7 | haines junction
# Processing Record 39 of Set 7 | east london
# Processing Record 40 of Set 7 | benemerito de las americas
# Processing Record 41 of Set 7 | maarianhamina
# Processing Record 42 of Set 7 | ribeira grande
# Processing Record 43 of Set 7 | tateyama
# Processing Record 44 of Set 7 | saint-philippe
# Processing Record 45 of Set 7 | zumarraga
# Processing Record 46 of Set 7 | rawah
# Processing Record 47 of Set 7 | belmonte
# Processing Record 48 of Set 7 | morondava
# Processing Record 49 of Set 7 | sitka
# Processing Record 50 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 8 | guerrero negro
# Processing Record 2 of Set 8 | roma
# Processing Record 3 of Set 8 | vilhena
# Processing Record 4 of Set 8 | grindavik
# Processing Record 5 of Set 8 | ixtapa
# Processing Record 6 of Set 8 | chicama
# Processing Record 7 of Set 8 | ranong
# Processing Record 8 of Set 8 | bondoukou
# Processing Record 9 of Set 8 | kaduqli
# Processing Record 10 of Set 8 | george
# Processing Record 11 of Set 8 | viedma
# Processing Record 12 of Set 8 | jamame
# Processing Record 13 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 14 of Set 8 | juneau
# Processing Record 15 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 8 | boulder
# Processing Record 17 of Set 8 | beyla
# Processing Record 18 of Set 8 | ouesso
# Processing Record 19 of Set 8 | aklavik
# Processing Record 20 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 21 of Set 8 | ossora
# Processing Record 22 of Set 8 | chichawatni
# Processing Record 23 of Set 8 | alugan
# Processing Record 24 of Set 8 | oktyabrskiy
# Processing Record 25 of Set 8 | bereda
# Processing Record 26 of Set 8 | nome
# Processing Record 27 of Set 8 | kidal
# Processing Record 28 of Set 8 | chimore
# Processing Record 29 of Set 8 | kununurra
# Processing Record 30 of Set 8 | villa carlos paz
# Processing Record 31 of Set 8 | vao
# Processing Record 32 of Set 8 | alofi
# Processing Record 33 of Set 8 | kamenka
# Processing Record 34 of Set 8 | capreol
# Processing Record 35 of Set 8 | caborca
# Processing Record 36 of Set 8 | prince rupert
# Processing Record 37 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 8 | pangai
# Processing Record 39 of Set 8 | verkhoyansk
# Processing Record 40 of Set 8 | caravelas
# Processing Record 41 of Set 8 | auki
# Processing Record 42 of Set 8 | sisimiut
# Processing Record 43 of Set 8 | port lincoln
# Processing Record 44 of Set 8 | mount gambier
# Processing Record 45 of Set 8 | floro
# Processing Record 46 of Set 8 | stokmarknes
# Processing Record 47 of Set 8 | barentu
# Processing Record 48 of Set 8 | sioux lookout
# Processing Record 49 of Set 8 | grand gaube
# Processing Record 50 of Set 8 | necochea
# Processing Record 1 of Set 9 | yumen
# Processing Record 2 of Set 9 | korcula
# Processing Record 3 of Set 9 | bolshaya atnya
# City not found. Skipping...
# Processing Record 4 of Set 9 | rorvik
# Processing Record 5 of Set 9 | pisco
# Processing Record 6 of Set 9 | roros
# Processing Record 7 of Set 9 | tuktoyaktuk
# Processing Record 8 of Set 9 | huarmey
# Processing Record 9 of Set 9 | bilibino
# Processing Record 10 of Set 9 | cockburn town
# Processing Record 11 of Set 9 | zhangye
# Processing Record 12 of Set 9 | graikokhorion
# City not found. Skipping...
# Processing Record 13 of Set 9 | la ronge
# Processing Record 14 of Set 9 | stephenville crossing
# Processing Record 15 of Set 9 | kpandae
# Processing Record 16 of Set 9 | naron
# Processing Record 17 of Set 9 | te anau
# Processing Record 18 of Set 9 | duldurga
# Processing Record 19 of Set 9 | yinchuan
# Processing Record 20 of Set 9 | shakawe
# Processing Record 21 of Set 9 | barra do garcas
# Processing Record 22 of Set 9 | le port
# Processing Record 23 of Set 9 | kerman
# Processing Record 24 of Set 9 | ouallam
# Processing Record 25 of Set 9 | paita
# Processing Record 26 of Set 9 | atherton
# Processing Record 27 of Set 9 | marsabit
# Processing Record 28 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 9 | cristalina
# Processing Record 30 of Set 9 | salinopolis
# Processing Record 31 of Set 9 | pacasmayo
# Processing Record 32 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 9 | mogwase
# Processing Record 34 of Set 9 | samarai
# Processing Record 35 of Set 9 | progreso
# Processing Record 36 of Set 9 | otane
# Processing Record 37 of Set 9 | udachnyy
# Processing Record 38 of Set 9 | northam
# Processing Record 39 of Set 9 | west wendover
# Processing Record 40 of Set 9 | jardim
# Processing Record 41 of Set 9 | ha tinh
# Processing Record 42 of Set 9 | castrillon
# Processing Record 43 of Set 9 | tutoia
# Processing Record 44 of Set 9 | birjand
# Processing Record 45 of Set 9 | vila
# Processing Record 46 of Set 9 | carutapera
# Processing Record 47 of Set 9 | moranbah
# Processing Record 48 of Set 9 | sfantu gheorghe
# Processing Record 49 of Set 9 | faanui
# Processing Record 50 of Set 9 | scottsbluff
# Processing Record 1 of Set 10 | elat
# Processing Record 2 of Set 10 | tessalit
# Processing Record 3 of Set 10 | narsaq
# Processing Record 4 of Set 10 | buala
# Processing Record 5 of Set 10 | iralaya
# Processing Record 6 of Set 10 | jiuquan
# Processing Record 7 of Set 10 | krasnyy kholm
# Processing Record 8 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 10 | rio claro
# Processing Record 10 of Set 10 | adre
# Processing Record 11 of Set 10 | tupik
# Processing Record 12 of Set 10 | moroni
# Processing Record 13 of Set 10 | barreirinhas
# Processing Record 14 of Set 10 | san quintin
# Processing Record 15 of Set 10 | klyuchi
# Processing Record 16 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 10 | mizdah
# Processing Record 18 of Set 10 | merke
# Processing Record 19 of Set 10 | puerto cabello
# Processing Record 20 of Set 10 | vuktyl
# Processing Record 21 of Set 10 | diamantino
# Processing Record 22 of Set 10 | buchanan
# Processing Record 23 of Set 10 | vestmannaeyjar
# Processing Record 24 of Set 10 | komyshuvakha
# Processing Record 25 of Set 10 | allende
# Processing Record 26 of Set 10 | hamilton
# Processing Record 27 of Set 10 | mehamn
# Processing Record 28 of Set 10 | abeche
# Processing Record 29 of Set 10 | the pas
# Processing Record 30 of Set 10 | bosaso
# Processing Record 31 of Set 10 | ballarat
# Processing Record 32 of Set 10 | xuddur
# Processing Record 33 of Set 10 | kijang
# Processing Record 34 of Set 10 | ranapur
# Processing Record 35 of Set 10 | oranjemund
# Processing Record 36 of Set 10 | troitskoye
# Processing Record 37 of Set 10 | taseyevo
# Processing Record 38 of Set 10 | rosarito
# Processing Record 39 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 40 of Set 10 | nanortalik
# Processing Record 41 of Set 10 | chifeng
# Processing Record 42 of Set 10 | lons-le-saunier
# Processing Record 43 of Set 10 | charyshskoye
# Processing Record 44 of Set 10 | molina
# Processing Record 45 of Set 10 | puerto el triunfo
# Processing Record 46 of Set 10 | esfahan
# Processing Record 47 of Set 10 | monaghan
# Processing Record 48 of Set 10 | tilichiki
# Processing Record 49 of Set 10 | burica
# City not found. Skipping...
# Processing Record 50 of Set 10 | angelholm
# City not found. Skipping...
# Processing Record 1 of Set 11 | miri
# Processing Record 2 of Set 11 | mulki
# Processing Record 3 of Set 11 | waingapu
# Processing Record 4 of Set 11 | souillac
# Processing Record 5 of Set 11 | the valley
# Processing Record 6 of Set 11 | high level
# Processing Record 7 of Set 11 | tabarqah
# City not found. Skipping...
# Processing Record 8 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 11 | venezuela
# Processing Record 10 of Set 11 | plaisance-du-touch
# Processing Record 11 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 12 of Set 11 | portland
# Processing Record 13 of Set 11 | lompoc
# Processing Record 14 of Set 11 | mana
# Processing Record 15 of Set 11 | shetpe
# Processing Record 16 of Set 11 | constitucion
# Processing Record 17 of Set 11 | nhulunbuy
# Processing Record 18 of Set 11 | algiers
# Processing Record 19 of Set 11 | tongchuan
# Processing Record 20 of Set 11 | yulara
# Processing Record 21 of Set 11 | severodvinsk
# Processing Record 22 of Set 11 | kontagora
# Processing Record 23 of Set 11 | trairi
# Processing Record 24 of Set 11 | qaqortoq
# Processing Record 25 of Set 11 | erenhot
# Processing Record 26 of Set 11 | maniitsoq
# Processing Record 27 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 11 | ugoofaaru
# Processing Record 29 of Set 11 | palmer
# Processing Record 30 of Set 11 | owo
# Processing Record 31 of Set 11 | san cristobal
# Processing Record 32 of Set 11 | korla
# Processing Record 33 of Set 11 | asau
# Processing Record 34 of Set 11 | san ramon
# Processing Record 35 of Set 11 | zhuhai
# Processing Record 36 of Set 11 | sumenep
# Processing Record 37 of Set 11 | galbshtadt
# Processing Record 38 of Set 11 | mahebourg
# Processing Record 39 of Set 11 | altamira
# Processing Record 40 of Set 11 | nago
# Processing Record 41 of Set 11 | oum hadjer
# Processing Record 42 of Set 11 | mizan teferi
# Processing Record 43 of Set 11 | cidreira
# Processing Record 44 of Set 11 | ziniare
# Processing Record 45 of Set 11 | kemi
# Processing Record 46 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 47 of Set 11 | dawson
# Processing Record 48 of Set 11 | fukue
# Processing Record 49 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 50 of Set 11 | cochabamba
# Processing Record 1 of Set 12 | stony plain
# Processing Record 2 of Set 12 | takaungu
# Processing Record 3 of Set 12 | hirara
# Processing Record 4 of Set 12 | bambanglipuro
# Processing Record 5 of Set 12 | vitim
# Processing Record 6 of Set 12 | santa lucia
# Processing Record 7 of Set 12 | maturin
# Processing Record 8 of Set 12 | verkhnyaya toyma
# Processing Record 9 of Set 12 | krasnovishersk
# Processing Record 10 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 12 | bilma
# Processing Record 12 of Set 12 | odesskoye
# Processing Record 13 of Set 12 | margate
# Processing Record 14 of Set 12 | kindu
# Processing Record 15 of Set 12 | ponta delgada
# Processing Record 16 of Set 12 | kieta
# Processing Record 17 of Set 12 | dire
# Processing Record 18 of Set 12 | ridgecrest
# Processing Record 19 of Set 12 | eisiskes
# Processing Record 20 of Set 12 | taloqan
# Processing Record 21 of Set 12 | iqaluit
# Processing Record 22 of Set 12 | selu
# Processing Record 23 of Set 12 | chimbote
# Processing Record 24 of Set 12 | champasak
# Processing Record 25 of Set 12 | saint-augustin
# Processing Record 26 of Set 12 | burriana
# Processing Record 27 of Set 12 | batak
# Processing Record 28 of Set 12 | sao gabriel da cachoeira
# Processing Record 29 of Set 12 | tarakan
# Processing Record 30 of Set 12 | aakirkeby
# City not found. Skipping...
# Processing Record 31 of Set 12 | daru
# Processing Record 32 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 12 | takhtamygda
# Processing Record 34 of Set 12 | kirando
# Processing Record 35 of Set 12 | tottori
# Processing Record 36 of Set 12 | nuuk
# Processing Record 37 of Set 12 | krosno
# Processing Record 38 of Set 12 | minab
# Processing Record 39 of Set 12 | bhongir
# Processing Record 40 of Set 12 | erzin
# Processing Record 41 of Set 12 | nishihara
# Processing Record 42 of Set 12 | port blair
# Processing Record 43 of Set 12 | cap malheureux
# Processing Record 44 of Set 12 | marzuq
# Processing Record 45 of Set 12 | newport
# Processing Record 46 of Set 12 | atambua
# Processing Record 47 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 12 | inirida
# Processing Record 49 of Set 12 | cap-aux-meules
# Processing Record 50 of Set 12 | joshimath
# Processing Record 1 of Set 13 | karratha
# Processing Record 2 of Set 13 | paamiut
# Processing Record 3 of Set 13 | bonavista
# Processing Record 4 of Set 13 | aracuai
# Processing Record 5 of Set 13 | luwuk
# Processing Record 6 of Set 13 | finnsnes
# Processing Record 7 of Set 13 | avallon
# Processing Record 8 of Set 13 | tingo maria
# Processing Record 9 of Set 13 | gushikawa
# Processing Record 10 of Set 13 | shu
# Processing Record 11 of Set 13 | nyurba
# Processing Record 12 of Set 13 | aksarka
# Processing Record 13 of Set 13 | qinzhou
# Processing Record 14 of Set 13 | chernyshevskiy
# Processing Record 15 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 16 of Set 13 | naze
# Processing Record 17 of Set 13 | katsuura
# Processing Record 18 of Set 13 | limbang
# Processing Record 19 of Set 13 | cicciano
# Processing Record 20 of Set 13 | rawson
# Processing Record 21 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 13 | bethanien
# Processing Record 23 of Set 13 | gurupa
# Processing Record 24 of Set 13 | ligayan
# Processing Record 25 of Set 13 | maumere
# Processing Record 26 of Set 13 | vila franca do campo
# Processing Record 27 of Set 13 | millbrook
# Processing Record 28 of Set 13 | abu jubayhah
# City not found. Skipping...
# Processing Record 29 of Set 13 | deputatskiy
# Processing Record 30 of Set 13 | mitu
# Processing Record 31 of Set 13 | oriximina
# Processing Record 32 of Set 13 | santa maria
# Processing Record 33 of Set 13 | albacete
# Processing Record 34 of Set 13 | loksa
# Processing Record 35 of Set 13 | beypur
# City not found. Skipping...
# Processing Record 36 of Set 13 | boende
# Processing Record 37 of Set 13 | somanda
# Processing Record 38 of Set 13 | gat
# Processing Record 39 of Set 13 | panindicuaro
# Processing Record 40 of Set 13 | bam
# Processing Record 41 of Set 13 | ahipara
# Processing Record 42 of Set 13 | kirya
# Processing Record 43 of Set 13 | mitsamiouli
# Processing Record 44 of Set 13 | ostrovnoy
# Processing Record 45 of Set 13 | vestmanna
# Processing Record 46 of Set 13 | miraflores
# Processing Record 47 of Set 13 | henties bay
# Processing Record 48 of Set 13 | frankfurt
# Processing Record 49 of Set 13 | luau
# Processing Record 50 of Set 13 | monroe
# Processing Record 1 of Set 14 | ovsyanka
# Processing Record 2 of Set 14 | tabukiniberu
# City not found. Skipping...
# Processing Record 3 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 14 | honiara
# Processing Record 5 of Set 14 | port-de-paix
# City not found. Skipping...
# Processing Record 6 of Set 14 | sorland
# Processing Record 7 of Set 14 | son la
# Processing Record 8 of Set 14 | sao borja
# Processing Record 9 of Set 14 | eureka
# Processing Record 10 of Set 14 | zhanaozen
# Processing Record 11 of Set 14 | aleksandrov gay
# Processing Record 12 of Set 14 | lima
# Processing Record 13 of Set 14 | nurota
# Processing Record 14 of Set 14 | bafoulabe
# Processing Record 15 of Set 14 | tanshui
# City not found. Skipping...
# Processing Record 16 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 17 of Set 14 | saint-michel-des-saints
# Processing Record 18 of Set 14 | strezhevoy
# Processing Record 19 of Set 14 | benguela
# Processing Record 20 of Set 14 | ulladulla
# Processing Record 21 of Set 14 | akyab
# Processing Record 22 of Set 14 | mvuma
# Processing Record 23 of Set 14 | nisia floresta
# Processing Record 24 of Set 14 | parras
# City not found. Skipping...
# Processing Record 25 of Set 14 | los algarrobos
# Processing Record 26 of Set 14 | isangel
# Processing Record 27 of Set 14 | athens
# Processing Record 28 of Set 14 | sterling
# Processing Record 29 of Set 14 | ilulissat
# Processing Record 30 of Set 14 | payakumbuh
# Processing Record 31 of Set 14 | tshikapa
# Processing Record 32 of Set 14 | doha
# Processing Record 33 of Set 14 | aloleng
# Processing Record 34 of Set 14 | umea
# Processing Record 35 of Set 14 | beringovskiy
# Processing Record 36 of Set 14 | zhezkazgan
# Processing Record 37 of Set 14 | lerwick
# Processing Record 38 of Set 14 | alvik
# Processing Record 39 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 14 | sola
# Processing Record 41 of Set 14 | montpellier
# Processing Record 42 of Set 14 | jacareacanga
# Processing Record 43 of Set 14 | guia de isora
# Processing Record 44 of Set 14 | pangody
# Processing Record 45 of Set 14 | marsh harbour
# Processing Record 46 of Set 14 | witu
# Processing Record 47 of Set 14 | okhotsk
# Processing Record 48 of Set 14 | antofagasta
# Processing Record 49 of Set 14 | marrakesh
# Processing Record 50 of Set 14 | pogar
# Processing Record 1 of Set 15 | imeni poliny osipenko
# Processing Record 2 of Set 15 | virginia beach
# Processing Record 3 of Set 15 | maiduguri
# Processing Record 4 of Set 15 | san-pedro
# Processing Record 5 of Set 15 | yurya
# City not found. Skipping...
# Processing Record 6 of Set 15 | el carrizo
# Processing Record 7 of Set 15 | quechultenango
# Processing Record 8 of Set 15 | wajima
# Processing Record 9 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 10 of Set 15 | bobrovka
# Processing Record 11 of Set 15 | contai
# Processing Record 12 of Set 15 | dinghai
# Processing Record 13 of Set 15 | xining
# Processing Record 14 of Set 15 | upata
# Processing Record 15 of Set 15 | port-gentil
# Processing Record 16 of Set 15 | pensilvania
# Processing Record 17 of Set 15 | neiafu
# Processing Record 18 of Set 15 | mercedes
# Processing Record 19 of Set 15 | chapais
# Processing Record 20 of Set 15 | villa bruzual
# Processing Record 21 of Set 15 | kerki
# City not found. Skipping...
# Processing Record 22 of Set 15 | agaro
# Processing Record 23 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 15 | minna
# Processing Record 25 of Set 15 | san antonio
# Processing Record 26 of Set 15 | gillette
# Processing Record 27 of Set 15 | taywarah
# Processing Record 28 of Set 15 | kabelvag
# Processing Record 29 of Set 15 | sakaiminato
# Processing Record 30 of Set 15 | mataram
# Processing Record 31 of Set 15 | ibra
# Processing Record 32 of Set 15 | kungurtug
# Processing Record 33 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 34 of Set 15 | mineral wells
# Processing Record 35 of Set 15 | nguiu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(14)
# Out:
#                 City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            Magadan      RU  59.57  150.80     51.51        84          11
# 1        Yellowknife      CA  62.46 -114.35     59.56        77          75
# 2         Nikolskoye      RU  59.70   30.79     48.09        94         100
# 3             Touros      BR  -5.20  -35.46     77.50        73          73
# 4       Punta Arenas      CL -53.15  -70.92     46.51        71         100
# 5              Adrar      MR  20.50  -10.07     82.54        56         100
# 6            Ushuaia      AR -54.80  -68.30     47.82        66          75
# 7            Teguise      ES  29.06  -13.56     73.62        78          20
# 8   Praia Da Vitoria      PT  38.73  -27.07     76.75        88          75
# 9             Namibe      AO -15.20   12.15     64.89        87          68
# 10        Butaritari      KI   3.07  172.79     81.97        78           7
# 11       Kangaatsiaq      GL  68.31  -53.46     38.93        81         100
# 12       Gondanglegi      ID  -7.75  112.01     73.56        92          60
# 13        Porto Novo      BJ   6.50    2.60     76.82        87          99
#
#     Wind Speed      Current Description
# 0         3.04               Few Clouds
# 1         9.22            Broken Clouds
# 2        11.32            Moderate Rain
# 3        21.00            Broken Clouds
# 4         8.05          Overcast Clouds
# 5         7.07               Light Rain
# 6         6.91  Light Intensity Drizzle
# 7        17.27               Few Clouds
# 8         5.48            Broken Clouds
# 9        11.30            Broken Clouds
# 10       20.33                Clear Sky
# 11       16.69               Light Rain
# 12        7.67            Broken Clouds
# 13        7.74          Overcast Clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
